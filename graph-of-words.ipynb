# %% [markdown]
# # graph of words

# %% [markdown]
# ## datos - corpus introducciones revista CELL

# %%
import ast
import re
from nltk import sent_tokenize
import spacy
nlp = spacy.load('en')
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
from joblib import Parallel, delayed
import multiprocessing
import numpy as np
import networkx as nx
import community

# %%
data = open('corpus_cell.json','r')
data_cell=data.read()
data_cell = ast.literal_eval(data_cell)
introductions=[' '.join(item['introduction']) for item in data_cell]
introductions=[re.sub("[\(\[].*?[\)\]]", "", item) for item in introductions]
introductions=[x for x in introductions if len(x)>0]

# %% [markdown]
# ## clean text

# %%
data=open('stopwords.txt','r')
data_read = data.read()
stop_words=data_read.replace('\n',' ').split()

def clean(text):
    text=tokenizer.tokenize(text)
    text=[word.lower() for word in text]
    text=[word for word in text if word not in stop_words]
    text=[word for word in text if not word.isnumeric()]
    return text

n=multiprocessing.cpu_count()
texts=Parallel(n_jobs=n)(delayed(clean)(text) for text in introductions)

# %%
texts[0]
# Out:
# ['emerging',
#  'outbreak',
#  'zika',
#  'virus',
#  'americas',
#  'brought',
#  'obscure',
#  'pathogen',
#  'forefront',
#  'global',
#  'healthcare',
#  'transmitted',
#  'aedes',
#  'aegypti',
#  'albopictus',
#  'mosquitoes',
#  'zika',
#  'virus',
#  'infections',
#  'spread',
#  'international',
#  'travel',
#  'expanded',
#  'large',
#  'heavily',
#  'populated',
#  'regions',
#  'south',
#  'central',
#  'north',
#  'america',
#  'correlations',
#  'increase',
#  'zika',
#  'virus',
#  'infections',
#  'development',
#  'fetal',
#  'microcephaly',
#  'guillain',
#  'barré',
#  'syndrome',
#  'resulted',
#  'declaration',
#  'public',
#  'health',
#  'emergency',
#  'world',
#  'health',
#  'organization',
#  'call',
#  'fast',
#  'tracked',
#  'development',
#  'zika',
#  'virus',
#  'diagnostics',
#  'synthetic',
#  'biology',
#  'emerging',
#  'discipline',
#  'great',
#  'potential',
#  'respond',
#  'pandemics',
#  'increasing',
#  'ability',
#  'synthetic',
#  'biologists',
#  'repurpose',
#  'engineer',
#  'natural',
#  'biological',
#  'components',
#  'practical',
#  'applications',
#  'led',
#  'opportunities',
#  'molecular',
#  'diagnostics',
#  'previously',
#  'developed',
#  'biotechnologies',
#  'dramatically',
#  'lower',
#  'cost',
#  'technical',
#  'barriers',
#  'development',
#  'synthetic',
#  'biology',
#  'based',
#  'diagnostics',
#  'technology',
#  'programmable',
#  'rna',
#  'sensors',
#  'called',
#  'toehold',
#  'switches',
#  'rationally',
#  'designed',
#  'bind',
#  'sense',
#  'virtually',
#  'rna',
#  'sequence',
#  'technology',
#  'freeze',
#  'dried',
#  'paper',
#  'based',
#  'cell',
#  'free',
#  'protein',
#  'expression',
#  'platform',
#  'deployment',
#  'toehold',
#  'switch',
#  'sensors',
#  'research',
#  'laboratory',
#  'providing',
#  'sterile',
#  'abiotic',
#  'method',
#  'storage',
#  'distribution',
#  'genetic',
#  'circuits',
#  'room',
#  'temperature',
#  'combined',
#  'technologies',
#  'create',
#  'platform',
#  'rapidly',
#  'inexpensively',
#  'developing',
#  'deploying',
#  'diagnostic',
#  'sensors',
#  'context',
#  'zika',
#  'virus',
#  'outbreak',
#  'paper',
#  'based',
#  'sensors',
#  'offer',
#  'solution',
#  'critical',
#  'challenges',
#  'facing',
#  'diagnosis',
#  'virus',
#  'standard',
#  'serological',
#  'approaches',
#  'antibody',
#  'detection',
#  'limited',
#  'diagnostic',
#  'due',
#  'cross',
#  'reactivity',
#  'patients',
#  'previously',
#  'infected',
#  'flaviviruses',
#  'circulating',
#  'region',
#  'result',
#  'accurate',
#  'diagnosis',
#  'requires',
#  'nucleic',
#  'acid',
#  'based',
#  'detection',
#  'methods',
#  'pcr',
#  'isothermal',
#  'nucleic',
#  'acid',
#  'amplification',
#  'techniques',
#  'expensive',
#  'require',
#  'technical',
#  'expertise',
#  'run',
#  'interpret',
#  'utilize',
#  'equipment',
#  'incompatible',
#  'remote',
#  'low',
#  'resource',
#  'locations',
#  'surveillance',
#  'containment',
#  'critically',
#  'needed',
#  'demonstrate',
#  'rapid',
#  'development',
#  'diagnostic',
#  'workflow',
#  'sequence',
#  'specific',
#  'detection',
#  'zika',
#  'virus',
#  'employed',
#  'low',
#  'resource',
#  'settings',
#  'addressed',
#  'limitations',
#  'practical',
#  'deployment',
#  'nucleic',
#  'acid',
#  'based',
#  'molecular',
#  'diagnostics',
#  'combining',
#  'isothermal',
#  'rna',
#  'amplification',
#  'toehold',
#  'switch',
#  'sensors',
#  'freeze',
#  'dried',
#  'paper',
#  'based',
#  'platform',
#  'automate',
#  'amplification',
#  'primer',
#  'sensor',
#  'design',
#  'process',
#  'silico',
#  'algorithms',
#  'demonstrate',
#  'high',
#  'throughput',
#  'pipeline',
#  'assemble',
#  'test',
#  'zika',
#  'sensors',
#  'hr',
#  'clinically',
#  'relevant',
#  'sensitivity',
#  'attained',
#  'amplification',
#  'detection',
#  'scheme',
#  'report',
#  'significant',
#  'detection',
#  'closely',
#  'related',
#  'dengue',
#  'virus',
#  'increase',
#  'diagnostic',
#  'capabilities',
#  'develop',
#  'crispr',
#  'cas9',
#  'based',
#  'module',
#  'discriminates',
#  'zika',
#  'genotypes',
#  'single',
#  'base',
#  'resolution',
#  'finally',
#  'employ',
#  'simple',
#  'sample',
#  'preparation',
#  'protocol',
#  'reliably',
#  'extract',
#  'viral',
#  'rna',
#  'demonstrate',
#  'robust',
#  'detection',
#  'scheme',
#  'active',
#  'zika',
#  'virus',
#  'samples']

# %% [markdown]
# ## grafos!

# %%
def graph_unweighted(text,K):
    text=clean(text)
    unique_words=list(set(text))
    G=nx.Graph()
    for word in unique_words:
        G.add_node(word)
    for word in text: ## recorremos el texto y encontramos los indices de todas las aparicions de word (index_word)
        index_word=[index for index, value in enumerate(text) if value == word]
        ## ahora buscamos las palabras vecinas en una ventana de largo K (hacia adelante)
        for index in index_word:
            for k in range(1,K+1):
                if index+k in range(len(text)):
                    if G.has_edge(text[index],text[index+k])==False:
                        G.add_edge(text[index],text[index+k])
    
    return G

def graph_weighted(text,K):
    text=clean(text)
    unique_words=list(set(text))
    G=nx.Graph()
    for word in unique_words:
        G.add_node(word)
    for word in text: ## recorremos el texto y encontramos los indices de todas las aparicions de word (index_word)
        index_word=[index for index, value in enumerate(text) if value == word]
        ## ahora buscamos las palabras vecinas en una ventana de largo K (hacia adelante)
        for index in index_word:
            for k in range(1,K+1):
                if index+k in range(len(text)):
                    if G.has_edge(text[index],text[index+k])==False:
                        G.add_edge(text[index],text[index+k],weight=1)
                    else:
                        x=G[text[index]][text[index+k]]['weight']
                        G[text[index]][text[index+k]]['weight']=x+1
    
    return G

# %% [markdown]
# ## construimos los grafos y extraemos algunos rasgos de
# ### https://networkx.github.io/documentation/networkx-1.10/reference/algorithms.centrality.html

# %%
def features(text):
    d={}
    G=graph_unweighted(text,4)
    d['degree']=nx.degree_centrality(G)
    d['closeness']=nx.closeness_centrality(G)
    d['betweenness']=nx.betweenness_centrality(G)
    partition=community.best_partition(G.to_undirected())
    d['number_communities']=len(list(set(partition.values())))
    
    return d

graph_features=Parallel(n_jobs=multiprocessing.cpu_count())(delayed(features)(text) for text in introductions)

# %%
graph_features[0]
# Out:
# {'betweenness': {'48': 0.0018815695650554925,
#   '7': 0.0010555616626659811,
#   'ability': 0.00031066851971415176,
#   'abiotic': 0.0016076681106606634,
#   'accurate': 0.001743278506868565,
#   'acid': 0.012422858663428791,
#   'active': 0.0008721118849199547,
#   'addressed': 0.001171427638210541,
#   'aedes': 0.004372496752111652,
#   'aegypti': 0.006325085064876688,
#   'albopictus': 0.004798808628448773,
#   'algorithms': 0.000782158857817708,
#   'america': 0.010221997846321038,
#   'americas': 0.003010152806771594,
#   'amplification': 0.05843237439774792,
#   'antibody': 0.0009119979766195564,
#   'applications': 0.002046380137342479,
#   'approaches': 0.0007428219356763294,
#   'assemble': 0.0038793228148341205,
#   'attained': 0.00047592369082462787,
#   'automate': 0.0014680100889753974,
#   'barriers': 0.002054777727559894,
#   'barré': 0.01038159235570388,
#   'base': 0.0068301517611687465,
#   'based': 0.12510229588990007,
#   'bind': 0.0005301883076436343,
#   'biological': 0.0007548340979687019,
#   'biologists': 0.0007784110265561221,
#   'biology': 0.014606606447435864,
#   'biotechnologies': 0.0011611869495267346,
#   'brought': 0.004798965492988,
#   'call': 0.012174690946346324,
#   'called': 0.0006071218506965664,
#   'capabilities': 0.0006309090823693979,
#   'cas9': 0.0006530675133246197,
#   'cell': 6.202251677364799e-05,
#   'central': 0.0010582162724334725,
#   'challenges': 0.0014955976546536071,
#   'circuits': 0.00043994360847229207,
#   'circulating': 0.0010602418232268697,
#   'clinically': 0.0020166606604832783,
#   'closely': 0.0009892599192572935,
#   'combined': 0.008061439803101028,
#   'combining': 0.00034470680417783274,
#   'components': 0.0006422689521614246,
#   'containment': 0.0011124488176631159,
#   'context': 0.0012083437282454112,
#   'correlations': 0.005271797712638307,
#   'cost': 0.0012706617285920768,
#   'create': 0.0032249176536602855,
#   'crispr': 0.0005904170976783258,
#   'critical': 0.0013145084606906226,
#   'critically': 0.0019418326498427216,
#   'cross': 0.003906430780888849,
#   'declaration': 0.00024798862773229766,
#   'demonstrate': 0.04451594924123221,
#   'dengue': 0.0007601755121987868,
#   'deploying': 0.004459335449999699,
#   'deployment': 0.014379527802184166,
#   'design': 0.0015130651854656227,
#   'designed': 0.00018487932886970256,
#   'detection': 0.06996126858920375,
#   'develop': 0.0006465258566956199,
#   'developed': 0.0006036832623618663,
#   'developing': 0.002650196259479716,
#   'development': 0.08396828122737394,
#   'diagnosis': 0.020628305062900285,
#   'diagnostic': 0.06737830249428645,
#   'diagnostics': 0.0705581302195503,
#   'discipline': 0.0015066961629294144,
#   'discriminates': 0.0013951007862500167,
#   'distribution': 0.0008825007177296807,
#   'dramatically': 0.0010363157414493291,
#   'dried': 0.0020025573841870063,
#   'due': 0.0015153379556021478,
#   'emergency': 0.00048815285007829736,
#   'emerging': 0.00858817622219935,
#   'employ': 0.0009506025474624408,
#   'employed': 0.0018388857111553047,
#   'engineer': 0.0017182915998475528,
#   'equipment': 0.0021428585797003304,
#   'expanded': 0.0008776773757095833,
#   'expensive': 0.003012832820149532,
#   'expertise': 0.0006746361949162735,
#   'expression': 0.0002557353677249949,
#   'extract': 0.0037497667779501044,
#   'facing': 0.000600953707257673,
#   'fast': 0.009981921915273218,
#   'fetal': 0.008566658892380853,
#   'finally': 0.001223690021970665,
#   'flaviviruses': 0.0005055442063179207,
#   'forefront': 0.0001790244012263798,
#   'free': 8.738512644429148e-05,
#   'freeze': 0.0026528694421187695,
#   'genetic': 0.00044974477531947287,
#   'genotypes': 0.006208494623453529,
#   'global': 0.00011958769516091086,
#   'great': 0.00011950641967633062,
#   'guillain': 0.006350008595135901,
#   'health': 0.003198869639881019,
#   'healthcare': 0.0001233631333588377,
#   'heavily': 0.0001747808136088737,
#   'high': 0.0006532786251498849,
#   'hr': 0.0015812135724487181,
#   'incompatible': 0.0015428601928259935,
#   'increase': 0.010458166569407859,
#   'increasing': 0.00019563990152225442,
#   'inexpensively': 0.005410998099678064,
#   'infected': 0.00044348855816537115,
#   'infections': 0.009914780479624071,
#   'international': 0.011136340377516641,
#   'interpret': 0.0011113663142486808,
#   'isothermal': 0.0035654322082625117,
#   'laboratory': 0.006343832391535983,
#   'large': 0.00020304947785093163,
#   'led': 0.003012721898779025,
#   'limitations': 0.001275592890845432,
#   'limited': 0.0006139129232542301,
#   'locations': 0.0006006090888286105,
#   'low': 0.02968062655236951,
#   'lower': 0.0020618111468955693,
#   'method': 0.001643267963925029,
#   'methods': 0.0,
#   'microcephaly': 0.009826703997081111,
#   'module': 0.0009241871243702189,
#   'molecular': 0.009102677205401468,
#   'mosquitoes': 0.002685151819503261,
#   'natural': 0.0014194314012126918,
#   'needed': 0.0035378900946278938,
#   'north': 0.009662889547988078,
#   'nucleic': 0.015430389118455621,
#   'obscure': 0.006336906149949751,
#   'offer': 0.0006746994571680473,
#   'opportunities': 0.001699831447430147,
#   'organization': 0.0028743757147790022,
#   'outbreak': 0.0030840678277899297,
#   'pandemics': 0.0001213898272721802,
#   'paper': 0.014957154813633937,
#   'pathogen': 0.003948518363341859,
#   'patients': 0.004412804440100368,
#   'pcr': 2.6893409246350426e-05,
#   'pipeline': 0.004500130289684967,
#   'platform': 0.05054920454191572,
#   'populated': 0.0001757750757222176,
#   'potential': 0.0001882726649131641,
#   'practical': 0.02011951427316465,
#   'preparation': 0.0008664433064902363,
#   'previously': 0.01438617773313152,
#   'primer': 0.0039002240024640167,
#   'process': 0.001914642068267758,
#   'programmable': 0.0010604977585043076,
#   'protein': 0.00017364146450006925,
#   'protocol': 0.004809044676265537,
#   'providing': 0.010170576672373356,
#   'public': 9.99333578519099e-05,
#   'rapid': 0.0013792511016692379,
#   'rapidly': 0.007944594898401816,
#   'rationally': 0.0008912953657496169,
#   'reactivity': 0.0033354276294919,
#   'region': 0.001038048145327373,
#   'regions': 0.0001767693378355615,
#   'related': 0.001244533236072836,
#   'relevant': 0.0009249901834351628,
#   'reliably': 0.005502734709267202,
#   'remote': 0.001152846482844973,
#   'report': 0.00034429838485615453,
#   'repurpose': 0.0012396823433325206,
#   'require': 0.00418846021731694,
#   'requires': 0.004830361811535842,
#   'research': 0.0044639479456231425,
#   'resolution': 0.010827412720810796,
#   'resource': 0.024479314019949548,
#   'respond': 0.00011886527723631798,
#   'result': 0.001807045272171673,
#   'resulted': 0.0006134534034087157,
#   'rna': 0.051017821062772625,
#   'robust': 0.0035523659533268134,
#   'room': 0.0004377303730556533,
#   'run': 0.0009043655277936353,
#   'sample': 0.0007358762956617428,
#   'samples': 0.0,
#   'scheme': 0.008643241201503171,
#   'sense': 0.0006557364957157643,
#   'sensitivity': 0.0006776292449950546,
#   'sensor': 0.002498137351135108,
#   'sensors': 0.12207729751124709,
#   'sequence': 0.0172965008321797,
#   'serological': 0.0007527686811104974,
#   'settings': 0.0025165272067279457,
#   'significant': 0.0004604656389476592,
#   'silico': 0.0008282142002809916,
#   'simple': 0.0008753837866488318,
#   'single': 0.004192276090986191,
#   'solution': 0.0010988040301354858,
#   'south': 0.00017776359994890541,
#   'specific': 0.00032868112563780517,
#   'spread': 0.005768939338722057,
#   'standard': 0.0004753474364406968,
#   'sterile': 0.016286149057422074,
#   'storage': 0.0014320486936361472,
#   'surveillance': 0.0018733339310599514,
#   'switch': 0.0054780895156173815,
#   'switches': 0.000747537650500166,
#   'syndrome': 0.0012333444725028428,
#   'synthetic': 0.07001372000812235,
#   'technical': 0.027923161812462613,
#   'techniques': 0.0017416603866511472,
#   'technologies': 0.005657210183348928,
#   'technology': 0.0072475648811754145,
#   'temperature': 0.00701300643963741,
#   'test': 0.0033943832103704445,
#   'throughput': 0.0007813653855728855,
#   'toehold': 0.010510170462144135,
#   'tracked': 0.007791048058720879,
#   'transmitted': 0.0001732423678923392,
#   'travel': 0.008570659656189035,
#   'utilize': 0.0019300434807021142,
#   'viral': 0.00603134256581602,
#   'virtually': 0.0006228073578779748,
#   'virus': 0.17887979746375332,
#   'workflow': 0.00076609396488315,
#   'world': 0.0010889094461454258,
#   'zika': 0.22570236998732013},
#  'closeness': {'48': 0.3769100169779287,
#   '7': 0.375,
#   'ability': 0.3079056865464632,
#   'abiotic': 0.25995316159250587,
#   'accurate': 0.3070539419087137,
#   'acid': 0.39431616341030196,
#   'active': 0.3847487001733102,
#   'addressed': 0.3358547655068079,
#   'aedes': 0.3490566037735849,
#   'aegypti': 0.36097560975609755,
#   'albopictus': 0.3627450980392157,
#   'algorithms': 0.314002828854314,
#   'america': 0.36333878887070375,
#   'americas': 0.3639344262295082,
#   'amplification': 0.42857142857142855,
#   'antibody': 0.37373737373737376,
#   'applications': 0.3333333333333333,
#   'approaches': 0.376271186440678,
#   'assemble': 0.38275862068965516,
#   'attained': 0.34312210200927357,
#   'automate': 0.35980551053484605,
#   'barriers': 0.3769100169779287,
#   'barré': 0.32408759124087594,
#   'base': 0.3523809523809524,
#   'based': 0.49887640449438203,
#   'bind': 0.33383458646616543,
#   'biological': 0.2820838627700127,
#   'biologists': 0.3087621696801113,
#   'biology': 0.42610364683301344,
#   'biotechnologies': 0.33893129770992364,
#   'brought': 0.36156351791530944,
#   'call': 0.3645320197044335,
#   'called': 0.3452566096423017,
#   'capabilities': 0.38608695652173913,
#   'cas9': 0.3894736842105263,
#   'cell': 0.346875,
#   'central': 0.2886866059817945,
#   'challenges': 0.3781942078364566,
#   'circuits': 0.23149113660062565,
#   'circulating': 0.29959514170040485,
#   'clinically': 0.387434554973822,
#   'closely': 0.3645320197044335,
#   'combined': 0.29326287978863935,
#   'combining': 0.373109243697479,
#   'components': 0.2820838627700127,
#   'containment': 0.3208092485549133,
#   'context': 0.3978494623655914,
#   'correlations': 0.3645320197044335,
#   'cost': 0.3425925925925926,
#   'create': 0.2928759894459103,
#   'crispr': 0.36333878887070375,
#   'critical': 0.3929203539823009,
#   'critically': 0.3463338533541342,
#   'cross': 0.35071090047393366,
#   'declaration': 0.2531356898517674,
#   'demonstrate': 0.40217391304347827,
#   'dengue': 0.37436762225969644,
#   'deploying': 0.39431616341030196,
#   'deployment': 0.38608695652173913,
#   'design': 0.3269513991163476,
#   'designed': 0.3074792243767313,
#   'detection': 0.45962732919254656,
#   'develop': 0.3867595818815331,
#   'developed': 0.33433734939759036,
#   'developing': 0.3535031847133758,
#   'development': 0.46443514644351463,
#   'diagnosis': 0.39015817223198596,
#   'diagnostic': 0.45121951219512196,
#   'diagnostics': 0.4723404255319149,
#   'discipline': 0.33433734939759036,
#   'discriminates': 0.38078902229845624,
#   'distribution': 0.2566473988439306,
#   'dramatically': 0.3378995433789954,
#   'dried': 0.375,
#   'due': 0.3501577287066246,
#   'emergency': 0.2717258261933905,
#   'emerging': 0.3908450704225352,
#   'employ': 0.275092936802974,
#   'employed': 0.3881118881118881,
#   'engineer': 0.31805157593123207,
#   'equipment': 0.2967914438502674,
#   'expanded': 0.2835249042145594,
#   'expensive': 0.33383458646616543,
#   'expertise': 0.2853470437017995,
#   'expression': 0.35294117647058826,
#   'extract': 0.3323353293413174,
#   'facing': 0.35071090047393366,
#   'fast': 0.3769100169779287,
#   'fetal': 0.376271186440678,
#   'finally': 0.28388746803069054,
#   'flaviviruses': 0.27543424317617865,
#   'forefront': 0.2717258261933905,
#   'free': 0.3490566037735849,
#   'freeze': 0.38341968911917096,
#   'genetic': 0.23149113660062565,
#   'genotypes': 0.38209982788296043,
#   'global': 0.27007299270072993,
#   'great': 0.3079056865464632,
#   'guillain': 0.33084947839046197,
#   'health': 0.2894393741851369,
#   'healthcare': 0.2707317073170732,
#   'heavily': 0.2723926380368098,
#   'high': 0.31444759206798867,
#   'hr': 0.375,
#   'incompatible': 0.2967914438502674,
#   'increase': 0.39361702127659576,
#   'increasing': 0.30662983425414364,
#   'inexpensively': 0.35406698564593303,
#   'infected': 0.2806573957016435,
#   'infections': 0.3847487001733102,
#   'international': 0.3639344262295082,
#   'interpret': 0.28498074454428757,
#   'isothermal': 0.39361702127659576,
#   'laboratory': 0.3323353293413174,
#   'large': 0.2723926380368098,
#   'led': 0.3384146341463415,
#   'limitations': 0.33636363636363636,
#   'limited': 0.34365325077399383,
#   'locations': 0.3062068965517241,
#   'low': 0.39713774597495527,
#   'lower': 0.3415384615384615,
#   'method': 0.2557603686635945,
#   'methods': 0.3651315789473684,
#   'microcephaly': 0.36333878887070375,
#   'module': 0.3801369863013699,
#   'molecular': 0.38408304498269896,
#   'mosquitoes': 0.36333878887070375,
#   'natural': 0.31759656652360513,
#   'needed': 0.3627450980392157,
#   'north': 0.35406698564593303,
#   'nucleic': 0.39431616341030196,
#   'obscure': 0.36097560975609755,
#   'offer': 0.3580645161290323,
#   'opportunities': 0.3384146341463415,
#   'organization': 0.3236151603498542,
#   'outbreak': 0.40437158469945356,
#   'pandemics': 0.3062068965517241,
#   'paper': 0.4269230769230769,
#   'pathogen': 0.3452566096423017,
#   'patients': 0.3298662704309064,
#   'pcr': 0.3687707641196013,
#   'pipeline': 0.36038961038961037,
#   'platform': 0.38608695652173913,
#   'populated': 0.2723926380368098,
#   'potential': 0.3070539419087137,
#   'practical': 0.3687707641196013,
#   'preparation': 0.2668269230769231,
#   'previously': 0.34365325077399383,
#   'primer': 0.35980551053484605,
#   'process': 0.3269513991163476,
#   'programmable': 0.376271186440678,
#   'protein': 0.35294117647058826,
#   'protocol': 0.3041095890410959,
#   'providing': 0.33084947839046197,
#   'public': 0.24860022396416573,
#   'rapid': 0.3657331136738056,
#   'rapidly': 0.3378995433789954,
#   'rationally': 0.3293768545994065,
#   'reactivity': 0.3298662704309064,
#   'region': 0.3004059539918809,
#   'regions': 0.2723926380368098,
#   'related': 0.37436762225969644,
#   'relevant': 0.35691318327974275,
#   'reliably': 0.32220609579100146,
#   'remote': 0.3,
#   'report': 0.3425925925925926,
#   'repurpose': 0.30919220055710306,
#   'require': 0.3333333333333333,
#   'requires': 0.36938435940099834,
#   'research': 0.33893129770992364,
#   'resolution': 0.3523809523809524,
#   'resource': 0.3881118881118881,
#   'respond': 0.3070539419087137,
#   'result': 0.3062068965517241,
#   'resulted': 0.2723926380368098,
#   'rna': 0.42045454545454547,
#   'robust': 0.38879159369527144,
#   'room': 0.23173277661795408,
#   'run': 0.2853470437017995,
#   'sample': 0.2781954887218045,
#   'samples': 0.36633663366336633,
#   'scheme': 0.4134078212290503,
